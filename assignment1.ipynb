# %% [markdown]
# # Welcome to Intro to data science assignment :)
# Run the below code to set up

# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot

pd.options.display.max_rows = 4000
pd.options.display.max_columns = 4000

path = os.getcwd()
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
list(csv_files)
# Out:
# ['D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Austria.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Belgium.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Denmark.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\France.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Germany.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Greece.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Italy.csv',
#  'D:\\Wei_Xiong\\University\\Y2S2\\Intro to Data science\\Assignment 1\\airbnb\\Airbnb-Data-Analysis\\Netherland.csv',
# ...

# %% [markdown]
# ##### Load a file into df

# %%
df = pd.read_csv("Austria.csv", sep = ';', low_memory=False)

# %% [markdown]
# ##### Load all files into df_all (very big)

# %%
df_all = pd.concat((pd.read_csv(f, header=0, sep = ';', low_memory=False) for f in csv_files))

# %%
df
# Out:
#             ID                            Listing Url       Scrape ID  \
# 0      9902936   https://www.airbnb.com/rooms/9902936  20170509084238
# 1     16932319  https://www.airbnb.com/rooms/16932319  20170509084238
# 2      4086303   https://www.airbnb.com/rooms/4086303  20170509084238
# 3     13112862  https://www.airbnb.com/rooms/13112862  20170509084238
# 4     16945823  https://www.airbnb.com/rooms/16945823  20170509084238
# ...        ...                                    ...             ...
# 7888  17749726  https://www.airbnb.com/rooms/17749726  20170509084238
# 7889  18304101  https://www.airbnb.com/rooms/18304101  20170509084238
# 7890    651121    https://www.airbnb.com/rooms/651121  20170509084238
# 7891   5982232   https://www.airbnb.com/rooms/5982232  20170509084238
# 7892   9078659   https://www.airbnb.com/rooms/9078659  20170509084238
#
#      Last Scraped                                               Name  \
# ...
